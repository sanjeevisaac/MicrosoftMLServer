# %%
import os
#Source Image Folder
image_location = os.path.abspath(os.path.join("C:\\workshop\\ImageSimilarity\\", "kids_girls_shoes"))

#Load all the TIFF images
images = []
for file in [img for img in os.listdir(image_location)
if img.endswith(".tif")]:
   images.append(image_location + "\\" + file)

import pandas
image_df = pandas.DataFrame(data=dict(image=images))
print(image_df)

# Get the feature vectors of the images
# This requires a 4 step process:
# 1. Load the image(s) via the loadImage() transform
# 2. Resize the image(s) to the size required by the image model 
#    (224x224 for resnet models, 227x227 for the alexnet model)
# 3. Extract the pixels from the resized image(s) using the extractPixel() transform
# 4. Finally, featurize the image(s) via the featurizeImage() transform
from microsoftml import rx_featurize, load_image, resize_image, extract_pixels, featurize_image
image_vector = rx_featurize(data=image_df, ml_transforms=[
    load_image(cols=dict(Features="image")),
    resize_image(cols="Features", width=224, height=224), #Alexnet uses 227x227, resnet50 uses 224x224
    extract_pixels(cols="Features"),
    featurize_image(cols="Features", dnn_model="resnet50")])

print(image_vector.head())
# Out:
#                                                  image
# 0    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 1    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 2    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 3    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 4    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 5    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 6    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 7    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 8    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 9    C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 10   C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 11   C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 12   C:\workshop\ImageSimilarity\kids_girls_shoes\1...
# 13   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 14   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 15   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 16   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 17   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 18   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 19   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 20   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 21   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 22   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 23   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 24   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 25   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 26   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 27   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 28   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# 29   C:\workshop\ImageSimilarity\kids_girls_shoes\2...
# ..                                                 ...
# 601  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 602  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 603  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 604  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 605  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 606  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 607  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 608  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 609  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 610  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 611  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 612  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 613  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 614  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 615  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 616  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 617  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 618  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 619  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 620  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 621  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 622  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 623  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 624  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 625  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 626  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 627  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 628  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 629  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
# 630  C:\workshop\ImageSimilarity\kids_girls_shoes\8...
#
# [631 rows x 1 columns]
# Beginning processing data.
# Rows Read: 631, Read Time: 0, Transform Time: 0
# Beginning processing data.
# Elapsed time: 00:03:42.2203012
# Finished writing 631 rows.
# Writing completed.
#                                                image  Features.0  Features.1  \
# 0  C:\workshop\ImageSimilarity\kids_girls_shoes\1...    0.263791    0.124832
# 1  C:\workshop\ImageSimilarity\kids_girls_shoes\1...    0.000000    0.017269
# 2  C:\workshop\ImageSimilarity\kids_girls_shoes\1...    0.086943    0.001670
# 3  C:\workshop\ImageSimilarity\kids_girls_shoes\1...    0.000000    0.050771
# 4  C:\workshop\ImageSimilarity\kids_girls_shoes\1...    0.041506    0.000000
#
#    Features.2  Features.3  Features.4  Features.5  Features.6  Features.7  \
# 0    0.018232    0.301644    1.583595    0.288370    0.092955    0.544711
# 1    0.041463    0.316369    0.117711    1.041282    0.007731    0.021203
# 2    0.197831    0.019148    0.111261    1.308316    0.137112    0.171546
# 3    0.015423    0.489556    0.679948    0.127845    0.074129    0.418043
# 4    0.168901    0.000000    0.000000    1.483785    0.006850    0.027026
#
#    Features.8      ...        Features.2038  Features.2039  Features.2040  \
# 0    0.041385      ...             0.000000       0.000000       0.005151
# 1    0.009064      ...             0.014357       0.022548       0.066630
# 2    0.049365      ...             0.000000       1.376571       0.016336
# 3    0.144134      ...             0.429427       0.085813       0.130022
# 4    0.000000      ...             0.000000       0.131650       0.088771
#
#    Features.2041  Features.2042  Features.2043  Features.2044  Features.2045  \
# 0       0.034666       0.051280       1.536503       0.011991       5.182803
# 1       0.000000       0.000000       0.266490       0.055093       1.094033
# 2       0.000000       0.014897       0.973578       0.023483       1.553750
# 3       0.098932       0.293303       0.979677       0.409530       2.471535
# 4       0.090082       0.529686       0.398627       0.410021       1.171460
#
#    Features.2046  Features.2047
# 0       0.059200       0.377131
# 1       0.017889       0.429328
# 2       0.588210       0.075892
# 3       0.114141       0.405827
# 4       2.249201       0.189426
#
# [5 rows x 2049 columns]

# %%
image_location_match = os.path.abspath(os.path.join("C:\\workshop\\ImageSimilarity\\", "kids_girls_shoes_match"))
images_match = []
for file in [img for img in os.listdir(image_location_match)
if img.endswith(".tif")]:
   images_match.append(image_location_match + "\\" + file)

image_match_df = pandas.DataFrame(data=dict(image=images_match))
image_match_vectors = rx_featurize(data=image_match_df, ml_transforms=[
    load_image(cols=dict(Features="image")),
    resize_image(cols="Features", width=227, height=227),
    extract_pixels(cols="Features"),
    featurize_image(cols="Features", dnn_model="Alexnet")])
print(image_match_vectors.head())

matimg = image_vector.drop("image", axis=1).as_matrix()
matmat = image_match_vectors.drop("image", axis=1).as_matrix()

#Using Cosine Distance to find distances between feature vectors
from scipy.spatial.distance import cdist
distance = cdist(matimg, matmat)
# Out:
# Beginning processing data.
# Rows Read: 19, Read Time: 0, Transform Time: 0
# Beginning processing data.
# Elapsed time: 00:00:07.6546857
# Finished writing 19 rows.
# Writing completed.
#                                                image  Features.0  Features.1  \
# 0  C:\workshop\ImageSimilarity\kids_girls_shoes_m...         0.0         0.0
# 1  C:\workshop\ImageSimilarity\kids_girls_shoes_m...         0.0         0.0
# 2  C:\workshop\ImageSimilarity\kids_girls_shoes_m...         0.0         0.0
# 3  C:\workshop\ImageSimilarity\kids_girls_shoes_m...         0.0         0.0
# 4  C:\workshop\ImageSimilarity\kids_girls_shoes_m...         0.0         0.0
#
#    Features.2  Features.3  Features.4  Features.5  Features.6  Features.7  \
# 0    1.632986    0.000000         0.0    0.873705         0.0         0.0
# 1    1.154633    0.000000         0.0    2.121917         0.0         0.0
# 2    2.033399    0.000000         0.0    0.000000         0.0         0.0
# 3    0.000000    0.093332         0.0    0.000000         0.0         0.0
# 4    0.000000    0.000000         0.0    0.000000         0.0         0.0
#
#    Features.8      ...        Features.4086  Features.4087  Features.4088  \
# 0         0.0      ...             3.921386            0.0            0.0
# 1         0.0      ...             1.614837            0.0            0.0
# 2         0.0      ...             2.702394            0.0            0.0
# 3         0.0      ...             1.560063            0.0            0.0
# 4         0.0      ...             5.623634            0.0            0.0
#
#    Features.4089  Features.4090  Features.4091  Features.4092  Features.4093  \
# 0       0.878647       0.000000       0.000000       0.000000            0.0
# 1       0.000000       0.000000       0.000000       0.000000            0.0
# 2       0.889678       0.063250       1.870448       0.000000            0.0
# 3       0.000000       0.696713       0.000000       0.910541            0.0
# 4       0.000000       2.432389       0.000000       0.000000            0.0
#
#    Features.4094  Features.4095
# 0       1.719760            0.0
# 1       0.000000            0.0
# 2       0.000000            0.0
# 3       0.012545            0.0
# 4       3.566639            0.0
#
# [5 rows x 4097 columns]

# %%
import numpy as np
idx=1
sorted = np.argsort(distance[:,idx])
print(images_match[idx])
print(images[sorted[0]])
print(images[sorted[1]])
print(images[sorted[2]])
# Out:
# C:\workshop\ImageSimilarity\kids_girls_shoes_match\DP0203201717175691M.tif
# C:\workshop\ImageSimilarity\kids_girls_shoes\8305749_fpx.tif
# C:\workshop\ImageSimilarity\kids_girls_shoes\2023066_fpx.tif
# C:\workshop\ImageSimilarity\kids_girls_shoes\2037925_fpx.tif
